# %% [markdown]
# <a href="https://colab.research.google.com/github/mmtog/Valores-Atippicos/blob/main/Actividad_4_(Valores_At%C3%ADpicos_por_Dataframe).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo
data20=pd.read_csv("Gastos y costos 2020.csv")

# %%
data20.info()
data20.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3342 non-null   int64
#  1   FECHA        3342 non-null   object
#  2   FOLIO        3342 non-null   object
#  3   UUID         3342 non-null   object
#  4   RFC          3342 non-null   object
#  5   PROVEEDOR    3342 non-null   object
#  6   TIPO GASTO   3342 non-null   object
#  7   GASTO        3342 non-null   object
#  8   DESCRIPCION  3342 non-null   object
#  9   TC           3342 non-null   float64
#  10  IMPORTE      3342 non-null   float64
#  11  IVA          3342 non-null   float64
#  12  RET ISR      3342 non-null   float64
#  13  RET IVA      3342 non-null   float64
#  14  TOTAL MX     3342 non-null   float64
#  15  TOTAL SAT    3342 non-null   float64
#  16  TIPO         3342 non-null   object
#  17  STATUS       3342 non-null   object
# ...

# %%
data201= data20.drop(["Unnamed: 0","Columna1"], axis=1)
data201
# Out:
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# 2     2020-01-01  0001010100752163714102
# 3     2020-01-01                    3663
# 4     2020-01-01                    2849
# ...          ...                     ...
# 3337  2020-12-01                  125834
# 3338  2020-12-01                   37652
# 3339  2020-12-01                     160
# 3340  2020-12-01                  634875
# 3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# 4     EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  ENA7006081P0
# ...                                    ...           ...
# 3337  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5  SQS110113MU0
# ...

# %%
v_nulos=data201.isnull().sum()
v_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
data201.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   object
#  1   FOLIO        3342 non-null   object
#  2   UUID         3342 non-null   object
#  3   RFC          3342 non-null   object
#  4   PROVEEDOR    3342 non-null   object
#  5   TIPO GASTO   3342 non-null   object
#  6   GASTO        3342 non-null   object
#  7   DESCRIPCION  3342 non-null   object
#  8   TC           3342 non-null   float64
#  9   IMPORTE      3342 non-null   float64
#  10  IVA          3342 non-null   float64
#  11  RET ISR      3342 non-null   float64
#  12  RET IVA      3342 non-null   float64
#  13  TOTAL MX     3342 non-null   float64
#  14  TOTAL SAT    3342 non-null   float64
#  15  TIPO         3342 non-null   object
#  16  STATUS       3342 non-null   object
#  17  POLIZA       3342 non-null   object
# ...

# %%
Cuantitativas=data201.iloc[:,8:15]

# %%
Cualitativas=data201.iloc[:,[0,1,2,3,4,5,6,7,15,16,17]]

# %%
#Realizamos diagrama de caja y bigote de cada columna del dataframe
fig=plt.figure(figsize=(20,8))
Cuantitativas.plot(kind="box",vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Metdo aplicando desviacion estandar para encontrar los limites permitidos, encuentro los valores externos
y=Cuantitativas
Limite_Superior=y.mean()+3*y.std()
Limite_Inferior=y.mean()-3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido TC               4.251032
# IMPORTE      25167.992859
# IVA           4563.165637
# RET ISR        667.271992
# RET IVA        958.239955
# TOTAL MX     28488.002843
# TOTAL SAT    33250.398514
# dtype: float64
# Limite inferior permitido TC              -2.117814
# IMPORTE     -18869.298785
# IVA          -3523.520012
# RET ISR       -627.750813
# RET IVA       -839.215179
# TOTAL MX    -21455.655297
# TOTAL SAT   -25762.462834
# dtype: float64

# %%
#Obtenemos datos y los outliners se convierten en nulos en el dataframe
Cuantitativas1=Cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
Cuantitativas1
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00
# ...   ...       ...      ...      ...      ...       ...        ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %%
v_nulos=Cuantitativas1.isnull().sum()
v_nulos
# Out:
# TC            9
# IMPORTE      67
# IVA          58
# RET ISR      21
# RET IVA      74
# TOTAL MX     65
# TOTAL SAT    45
# dtype: int64

# %%
#Realizamos una copia del data
Cuantitativas_limpio=Cuantitativas1.copy()

# %%
#Reemplazamos valores atipicos (nulos) con mean
Cuantitativas_limpio=Cuantitativas_limpio.fillna(round(Cuantitativas1.mean(),1))
Cuantitativas_limpio
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00
# ...   ...       ...      ...      ...      ...       ...        ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %%
v_nulos=Cuantitativas_limpio.isnull().sum()
v_nulos
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
#Unimos valores cualitativos
V_limpios_2020=pd.concat([Cuantitativas_limpio,Cualitativas],axis=1)
V_limpios_2020
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  \
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00
# ...   ...       ...      ...      ...      ...       ...        ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# ...

# %%
#2021
data21=pd.read_csv("Gastos y costos 2021.csv")
data21.head()
# Out:
#    Unnamed: 0       FECHA                   FOLIO  \
# 0           0  2021-01-01  0001010100750847116902
# 1           1  2021-01-01  0001010100752163714102
# 2           2  2021-01-01                   19788
# 3           3  2021-01-01                  211781
# 4           4  2021-01-01                  211782
#
#                                    UUID           RFC  \
# 0  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# 1  B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1
# 2  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 3  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# 4  C16F79B5-FB35-4BFC-AF84-708B24F500BB  BLE1512082R9
#
#                                 PROVEEDOR                TIPO GASTO  \
# 0          BANCO NACIONAL DE MEXICO, S.A.         COMISION BANCARIA
# 1          BANCO NACIONAL DE MEXICO, S.A.         COMISION BANCARIA
# 2  ELECTRONICOS Y SIMILARES, S.A. DE C.V.                   COMPRAS
# ...

# %%
#Eliminar columnas incesarias
data212=data21.drop(["Unnamed: 0"],axis=1)
data212
# Out:
#            FECHA                   FOLIO  \
# 0     2021-01-01  0001010100750847116902
# 1     2021-01-01  0001010100752163714102
# 2     2021-01-01                   19788
# 3     2021-01-01                  211781
# 4     2021-01-01                  211782
# ...          ...                     ...
# 3030  2021-12-01                  127043
# 3031  2021-12-01                   11740
# 3032  2021-12-01              1092957089
# 3033  2021-12-01                  747826
# 3034  2021-12-01                 1227374
#
#                                       UUID           RFC  \
# 0     71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# 1     B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1
# 2     19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 3     EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# 4     C16F79B5-FB35-4BFC-AF84-708B24F500BB  BLE1512082R9
# ...                                    ...           ...
# 3030  83F82167-0D14-144E-9D76-045C95F25DDD  PGM881128QIA
# ...

# %%
data212.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3035 non-null   object
#  1   FOLIO        3035 non-null   object
#  2   UUID         3035 non-null   object
#  3   RFC          3035 non-null   object
#  4   PROVEEDOR    3035 non-null   object
#  5   TIPO GASTO   3035 non-null   object
#  6   DESCRIPCION  3035 non-null   object
#  7   MP           3035 non-null   object
#  8   TC           3035 non-null   float64
#  9   IMPORTE      3035 non-null   float64
#  10  IVA          3035 non-null   float64
#  11  RET ISR      3035 non-null   float64
#  12  RET IVA      3035 non-null   float64
#  13  TOTAL MX     3035 non-null   float64
#  14  TOTAL SAT    3035 non-null   float64
#  15  TIPO         3035 non-null   object
#  16  STATUS       3035 non-null   object
#  17  POLIZA       3035 non-null   object
# ...

# %%
Cuantitativas1=data212.iloc[:,8:15]

# %%
Cualitativas1=data212.iloc[:,[0,1,2,3,4,5,6,7,15,16,17]]

# %%
#Realizamos diagrama de caja y bigote de cada columna del dataframe
fig=plt.figure(figsize=(15,8))
data212.plot(kind="box",vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Metodo aplicando cuartiles encuentro cuartiles 0.25 y 0.75
y=Cuantitativas1

percentile25=y.quantile(0.25) #q1
percentile75=y.quantile(0.75) #q3
iqr=percentile75-percentile25

Limite_Superior_2021= percentile75+1.5*iqr
Limite_Inferior_2021=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_2021)
print("Limite inferior permitido", Limite_Inferior_2021)
# Out:
# Limite superior permitido TC               1.0000
# IMPORTE      10127.7125
# IVA           1381.4750
# RET ISR          0.0000
# RET IVA          0.0000
# TOTAL MX     11580.2750
# TOTAL SAT    11456.0225
# dtype: float64
# Limite inferior permitido TC              1.0000
# IMPORTE     -6076.6275
# IVA          -828.8850
# RET ISR         0.0000
# RET IVA         0.0000
# TOTAL MX    -6948.1650
# TOTAL SAT   -6818.3175
# dtype: float64

# %%
#Obtenemos datos y los outliners se convierten en nulos en el dataframe
Cuantitativas1_1=Cuantitativas1[(y<=Limite_Superior_2021)&(y>=Limite_Inferior_2021)]
Cuantitativas1_1
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0   490.00   78.40      0.0      0.0     568.4      568.4
# 1     1.0   345.00   55.20      0.0      0.0     400.2      400.2
# 2     1.0  3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3     1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4     1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...   ...      ...     ...      ...      ...       ...        ...
# 3030  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3031  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3032  1.0      NaN  705.58      0.0      0.0       NaN        NaN
# 3033  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3034  1.0      NaN    0.00      0.0      0.0       NaN        NaN
#
# [3035 rows x 7 columns]

# %%
v_nulos=Cuantitativas1_1.isnull().sum()
v_nulos
# Out:
# TC            24
# IMPORTE      336
# IVA          342
# RET ISR       56
# RET IVA      212
# TOTAL MX     347
# TOTAL SAT    351
# dtype: int64

# %%
#Realizamos copia del df
Cuantitativas_2021_limpio=Cuantitativas1_1.copy()

# %%
#Reemplazamos valores atípicos (nulos) del df con "mean"
Cuantitativas_2021_limpio=Cuantitativas_2021_limpio.fillna(round(Cuantitativas1_1.mean(),1))
Cuantitativas_2021_limpio
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0   490.00   78.40      0.0      0.0     568.4      568.4
# 1     1.0   345.00   55.20      0.0      0.0     400.2      400.2
# 2     1.0  3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3     1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4     1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...   ...      ...     ...      ...      ...       ...        ...
# 3030  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3031  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3032  1.0  1699.50  705.58      0.0      0.0    1903.4     1910.9
# 3033  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3034  1.0  1699.50    0.00      0.0      0.0    1903.4     1910.9
#
# [3035 rows x 7 columns]

# %%
V_limpios_2021=pd.concat([Cuantitativas_2021_limpio,Cualitativas1],axis=1)
V_limpios_2021
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT       FECHA  \
# 0     1.0   490.00   78.40      0.0      0.0     568.4      568.4  2021-01-01
# 1     1.0   345.00   55.20      0.0      0.0     400.2      400.2  2021-01-01
# 2     1.0  3447.41  551.59      0.0      0.0    3999.0     3999.0  2021-01-01
# 3     1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6  2021-01-01
# 4     1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3  2021-01-01
# ...   ...      ...     ...      ...      ...       ...        ...         ...
# 3030  1.0     0.00    0.00      0.0      0.0       0.0        0.0  2021-12-01
# 3031  1.0     0.00    0.00      0.0      0.0       0.0        0.0  2021-12-01
# 3032  1.0  1699.50  705.58      0.0      0.0    1903.4     1910.9  2021-12-01
# 3033  1.0     0.00    0.00      0.0      0.0       0.0        0.0  2021-12-01
# 3034  1.0  1699.50    0.00      0.0      0.0    1903.4     1910.9  2021-12-01
#
# ...

# %%
#2022
#Cargar archivo
data2=pd.read_csv("Gastos y costos 2022_sin_nulos.csv")

# %%
data2.head()
# Out:
#    Unnamed: 0       Fecha         Folio                                  UUID  \
# 0           0  2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1           1  2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2           2  2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3           3  2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4           4  2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
#
#              RFC                         Proveedor                TIPO GASTO  \
# 0   BLE1512082R9      BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 1   BLE1512082R9      BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 2   BNM840515VB1    BANCO NACIONAL DE MEXICO, S.A.         COMISION BANCARIA
# 3  ZEGC530520V4A  CARLOS ENRIQUE ZERMEÑO GUTIERREZ                   COMPRAS
# 4  ZEGC530520V4A  CARLOS ENRIQUE ZERMEÑO GUTIERREZ                   COMPRAS
#
# ...

# %%
#Eliminar columnas incesarias
data22=data2.drop(["Unnamed: 0","Otros"],axis=1)
data22
# Out:
#            Fecha         Folio                                  UUID  \
# 0     2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1     2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2     2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3     2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4     2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...          ...           ...                                   ...
# 2572  2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573  2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574  2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575  2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576  2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# ...

# %%
data22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        2577 non-null   object
#  1   Folio        2577 non-null   object
#  2   UUID         2577 non-null   object
#  3   RFC          2577 non-null   object
#  4   Proveedor    2577 non-null   object
#  5   TIPO GASTO   2577 non-null   object
#  6   Descripción  2577 non-null   object
#  7   MP           2577 non-null   object
#  8   TC           2577 non-null   float64
#  9   Importe      2577 non-null   float64
#  10  IVA          2577 non-null   float64
#  11  RET ISR      2577 non-null   float64
#  12  RET IVA      2577 non-null   float64
#  13  TOTAL MX     2577 non-null   float64
#  14  TOTAL SAT    2577 non-null   float64
#  15  Tipo         2577 non-null   object
#  16  Status       2577 non-null   object
#  17  Poliza       2577 non-null   object
# ...

# %%
Cuantitativas22=data22.iloc[:,8:15]

# %%
Cualitativas22=data22.iloc[:,[0,1,2,3,4,5,6,7,15,16,17]]

# %%
#Realizamos diagrama de caja y bigote de cada columna del dataframe
fig=plt.figure(figsize=(15,8))
data22.plot(kind="box",vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Metodo aplicando cuartiles encuentro cuartiles 0.25 y 0.75
y=Cuantitativas22

percentile25=y.quantile(0.25) #q1
percentile75=y.quantile(0.75) #q3
iqr=percentile75-percentile25

Limite_Superior_2022= percentile75+1.5*iqr
Limite_Inferior_2022=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_2022)
print("Limite inferior permitido", Limite_Inferior_2022)
# Out:
# Limite superior permitido TC               1.500
# Importe       9058.900
# IVA           1031.150
# RET ISR          0.000
# RET IVA          0.000
# TOTAL MX     10374.700
# TOTAL SAT    10485.475
# dtype: float64
# Limite inferior permitido TC              0.700
# Importe     -5435.340
# IVA          -618.690
# RET ISR         0.000
# RET IVA         0.000
# TOTAL MX    -6224.820
# TOTAL SAT   -6291.285
# dtype: float64

# %%
#Obtenemos datos y los outliners se convierten en nulos en el dataframe
Cuantitativas2_1=Cuantitativas22[(y<=Limite_Superior_2022)&(y>=Limite_Inferior_2022)]
Cuantitativas2_1
# Out:
#        TC  Importe     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6
# 1     1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3
# 2     1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3     1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 4     1.0     0.00    0.00      0.0      0.0       0.0        0.0
# ...   ...      ...     ...      ...      ...       ...        ...
# 2572  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 2573  1.0      NaN  516.32      0.0      0.0       NaN        NaN
# 2574  1.2     0.00    0.00      0.0      0.0       0.0        0.0
# 2575  1.2     0.00    0.00      0.0      0.0       0.0        0.0
# 2576  1.2     0.00    0.00      0.0      0.0       0.0        0.0
#
# [2577 rows x 7 columns]

# %%
v_nulos=Cuantitativas2_1.isnull().sum()
v_nulos
# Out:
# TC            18
# Importe      305
# IVA          303
# RET ISR       71
# RET IVA       70
# TOTAL MX     291
# TOTAL SAT    288
# dtype: int64

# %%
#Realizamos copia del df
Cuantitativas2022_limpio=Cuantitativas2_1.copy()

# %%
Cuantitativas_2022_limpio=Cuantitativas_2021_limpio.fillna(round(Cuantitativas1_1.mean(),1))
Cuantitativas_2022_limpio
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0   490.00   78.40      0.0      0.0     568.4      568.4
# 1     1.0   345.00   55.20      0.0      0.0     400.2      400.2
# 2     1.0  3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3     1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4     1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...   ...      ...     ...      ...      ...       ...        ...
# 3030  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3031  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3032  1.0  1699.50  705.58      0.0      0.0    1903.4     1910.9
# 3033  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3034  1.0  1699.50    0.00      0.0      0.0    1903.4     1910.9
#
# [3035 rows x 7 columns]

# %%
v_nulos_nulos=Cuantitativas_2022_limpio.isnull().sum()
v_nulos_nulos
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
V_limpios_2022=pd.concat([Cuantitativas_limpio,Cualitativas],axis=1)
V_limpios_2022
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  \
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00
# ...   ...       ...      ...      ...      ...       ...        ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# ...

# %%
#Cargar archivo
data3=pd.read_csv("Gastos y costos 2023_Sin_Nulos.csv")

data3.head()
# Out:
#    Unnamed: 0       Fecha   Folio                                  UUID  \
# 0           0  2023-01-01      31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1           1  2023-01-01      38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2           2  2023-01-01  341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3           3  2023-01-01  341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4           4  2023-01-01  342205  DCC10492-DE51-4C87-8430-5676FBF81931
#
#             RFC                     Proveedor                TIPO GASTO  \
# 0  AAE6411055P8     AESA ARTICULOS ELECTRICOS                   COMPRAS
# 1  AAE6411055P8     AESA ARTICULOS ELECTRICOS                   COMPRAS
# 2  BLE1512082R9  BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 3  BLE1512082R9  BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
# 4  BLE1512082R9  BEPENSA LEASING S.A. DE C.V.  ARRENDAMIENTO FINANCIERO
#
#                                          Descripción      MP      FP   TC  \
# ...

# %%
data3.head()
#Eliminar columnas incesarias
data23=data3.drop(["Unnamed: 0"],axis=1) # Remove extra brackets around column name
data23
data23.info()
Cuantitativas23=data23.iloc[:,8:15]
Cualitativas22=data23.iloc[:,[0,1,2,3,4,5,6,7,15,16,17]]
#Realizamos diagrama de caja y bigote de cada columna del dataframe
fig=plt.figure(figsize=(15,8))
data23.plot(kind="box",vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

#Metodo aplicando cuartiles encuentro cuartiles 0.25 y 0.75
y=Cuantitativas23

# Convert relevant columns to numeric, handling errors
for col in y.columns:
    try:
        y[col] = pd.to_numeric(y[col], errors='coerce')
    except:
        print(f"Could not convert column {col} to numeric")

percentile25=y.quantile(0.25) #q1
percentile75=y.quantile(0.75) #q3
iqr=percentile75-percentile25

Limite_Superior_2023= percentile75+1.5*iqr
Limite_Inferior_2023=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_2023)
print("Limite inferior permitido", Limite_Inferior_2023)

#Obtenemos datos y los outliners se convierten en nulos en el dataframe
Cuantitativas23_1=Cuantitativas23[(y<=Limite_Superior_2023)&(y>=Limite_Inferior_2023)]
Cuantitativas23_1

v_nulos=Cuantitativas23_1.isnull().sum()
v_nulos

#Realizamos copia del df
Cuantitativas2023_limpio=Cuantitativas23_1.copy()

Cuantitativas_2023_limpio=Cuantitativas_2021_limpio.fillna(round(Cuantitativas1_1.mean(),1))
Cuantitativas_2023_limpio

v_nulos_nulos=Cuantitativas_2023_limpio.isnull().sum()
v_nulos_nulos

V_limpios_2023=pd.concat([Cuantitativas_limpio,Cualitativas],axis=1)
V_limpios_2023
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        397 non-null    object
#  1   Folio        397 non-null    object
#  2   UUID         397 non-null    object
#  3   RFC          397 non-null    object
#  4   Proveedor    397 non-null    object
#  5   TIPO GASTO   397 non-null    object
#  6   Descripción  397 non-null    object
#  7   MP           397 non-null    object
#  8   FP           397 non-null    object
#  9   TC           397 non-null    float64
#  10  Importe      397 non-null    float64
#  11  IVA          397 non-null    float64
#  12  RET ISR      397 non-null    float64
#  13  RET IVA      397 non-null    float64
#  14  TOTAL MX     397 non-null    float64
#  15  TOTAL SAT    397 non-null    float64
#  16  Tipo         397 non-null    object
#  17  Status       397 non-null    object
# ...

# %%
V_limpios_2020.to_csv("Valores_atipicos_2020.csv")

# %%
V_limpios_2021.to_csv("Valores_atipicos_2021.csv")

# %%
V_limpios_2022.to_csv("Valores_atipicos_2022.csv")

# %%
V_limpios_2023.to_csv("Valores_atipicos_2023.csv")
